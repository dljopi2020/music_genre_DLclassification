# %%
import librosa
import os
import glob
import IPython.display as ipd
from pathlib import Path
import timeit
import time, sys

# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display

import pandas as pd
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import numpy as np
import cv2
import seaborn as sns

# %tensorflow_version 1.x #version 1 works without problems
import tensorflow


from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

import keras
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, plot_confusion_matrix
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense, BatchNormalization, Activation, GaussianNoise, LSTM
from sklearn.metrics import accuracy_score
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x #version 1 works without problems`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
#authorize colab to use data in google drive
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
#create path to dataset and check if it finds genres
DATA_DIR = Path('/content/gdrive/My Drive/genres/') 
genres = [x.name for x in DATA_DIR.glob('*') if x.is_dir()]
genres
# Out:
# ['blues',
#  'rock',
#  'classical',
#  'disco',
#  'hiphop',
#  'metal',
#  'pop',
#  'jazz',
#  'country',
#  'reggae']

# %%
def create_paths_ds(paths: Path, label: str) -> list:
    EXTENSION_TYPE = '.wav'
    return [(x, label) for x in paths.glob('*' + EXTENSION_TYPE)]

# %%
from collections import Counter

categories_to_use = [ #choose the genres used 
    'classical',
    'hiphop',
    'metal',
    'country',
    # 'reggae'
]

#overwriting classes to all classes
# categories_to_use = categories

NUM_CLASSES = len(categories_to_use)

print(f'Number of classes: {NUM_CLASSES}')

paths_all_labels = []
for cat in categories_to_use:
    paths_all_labels += create_paths_ds(DATA_DIR / cat, cat)

# for y in range(len(paths_all_labels)):
  # print (y)

# print([paths_all_labels[y][1] for y in range(len(paths_all_labels))])
 
X_train, X_test = train_test_split(paths_all_labels,test_size=0.1, stratify = [paths_all_labels[y][1] for y in range(len(paths_all_labels))] ) #fix stratified sampling for test data
X_train, X_val = train_test_split(X_train, test_size=0.2, stratify = [X_train[y][1] for y in range(len(X_train))] ) 


for i in categories_to_use:
  print('Number of train samples for '+i+': '+ str([X_train[y][1] for y in range(len(X_train))].count(i))) #checks whether train samples are equally divided
  print('Number of test samples for '+i+': '+ str([X_test[y][1] for y in range(len(X_test))].count(i))) #checks whether test samples are equally divided
  print('Number of validation samples for '+i+': '+ str([X_val[y][1] for y in range(len(X_val))].count(i))) #checks whether val samples are equally divided


print(f'Train length: {len(X_train)}')
print(f'Validation length: {len(X_val)}')
print(f'Test length: {len(X_test)}')
# Out:
# Number of classes: 4
# Number of train samples for classical: 72
# Number of test samples for classical: 10
# Number of validation samples for classical: 18
# Number of train samples for hiphop: 72
# Number of test samples for hiphop: 10
# Number of validation samples for hiphop: 18
# Number of train samples for metal: 72
# Number of test samples for metal: 10
# Number of validation samples for metal: 18
# Number of train samples for country: 72
# Number of test samples for country: 10
# Number of validation samples for country: 18
# Train length: 288
# Validation length: 72
# Test length: 40

# %%
def load_and_preprocess_cnn(dataset, SAMPLE_SIZE = 30):
    IMG_SIZE = (216,128) 
    progress = 0

    data = []
    labels = []
    for (path, label) in dataset:
        audio, sr = librosa.load(path)
        dur = librosa.get_duration(audio, sr = sr)
        sampleNum = int(dur / SAMPLE_SIZE)
        offset = (dur % SAMPLE_SIZE) / 2
        for i in range(sampleNum):
            audio, sr = librosa.load(path, offset= offset+i, duration=SAMPLE_SIZE)
            sample = librosa.feature.melspectrogram(audio, sr=sr)
            # print(sample.shape)
            sample = cv2.resize(sample, dsize=IMG_SIZE)
            sample = np.expand_dims(sample,-1) #the cnn needs 3 dimensions to work
            data += [(sample, label)]
            labels += [label]

        progress +=1
        print('\r Progress: '+str(round(100*progress/len(dataset))) + '%', end='')
    return data, labels

# %%
def load_and_preprocess_lstm(dataset, SAMPLE_SIZE = 30):
    IMG_SIZE = (216,128) 
    progress=0

    data = []
    labels = []
    for (path, label) in dataset:
        audio, sr = librosa.load(path)
        dur = librosa.get_duration(audio, sr = sr)
        sampleNum = int(dur / SAMPLE_SIZE)
        offset = (dur % SAMPLE_SIZE) / 2
        for i in range(sampleNum):
            audio, sr = librosa.load(path, offset= offset+i, duration=SAMPLE_SIZE)
            sample = librosa.feature.melspectrogram(audio, sr=sr)
            # print(sample.shape)
            sample = cv2.resize(sample, dsize=IMG_SIZE)
            data += [(sample, label)]
            labels += [label]
        progress +=1
        print('\r Progress: '+str(round(100*progress/len(dataset))) + '%', end='')
    return data, labels

# %%
def retrieve_samples(sample_size, model_type):

    if model_type == 'cnn':
  
        print("\nLoading train samples")
        X_train_samples, train_labels = load_and_preprocess_cnn(X_train,sample_size)
        print("\nLoading test samples")
        X_test_samples, test_labels = load_and_preprocess_cnn(X_test,sample_size)
        print("\nLoading val samples")
        X_val_samples, val_labels = load_and_preprocess_cnn(X_val,sample_size)
        print('\n')

    elif model_type == 'lstm':

        print("\nLoading train samples")
        X_train_samples, train_labels = load_and_preprocess_lstm(X_train,sample_size)
        print("\nLoading test samples")
        X_test_samples, test_labels = load_and_preprocess_lstm(X_test,sample_size)
        print("\nLoading val samples")
        X_val_samples, val_labels = load_and_preprocess_lstm(X_val,sample_size)      
        print('\n')

    # print("shape: " + str(X_train_samples[0][0].shape))
    # print("number of training samples: "+ str(len(X_train_samples)))
    # print("number of validation samples: "+ str(len(X_val_samples)))
    # print("number of test samples: "+ str(len(X_test_samples)))


    return X_train_samples, X_test_samples, X_val_samples

# %%
#Define Model

def create_cnn_model(input_shape):
  # input_shape = X_train_samples[0][0].shape

  model = Sequential()
  model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
  model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(GaussianNoise(0.1))
  model.add(Dropout(0.25))
  model.add(Flatten())
  model.add(Dense(128))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.5))
  model.add(Dense(NUM_CLASSES, activation='softmax')) #Compile
  model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.adam(), metrics=['accuracy'])
  # print(model.summary())
  return model

# %%
def create_lstm_model(input_shape):
    model = Sequential()

    model.add(LSTM(units = 512, dropout=0.5, recurrent_dropout=0.3, return_sequences = True, input_shape = input_shape))
    model.add(LSTM(units = 512, dropout=0.5, recurrent_dropout=0.3, return_sequences = False))
    model.add(Dense(units=NUM_CLASSES, activation='softmax'))#Compile

    model.compile(loss=tensorflow.keras.losses.categorical_crossentropy, optimizer='adam', metrics=['accuracy'])
    # print(model.summary())

    return model

# %%
def create_model_data_and_labels(X_train_samples, X_val_samples, X_test_samples):
    #Prepare samples to work for training the model
    labelizer = LabelEncoder()

    #prepare training data and labels
    x_train = np.array([x[0] for x in X_train_samples])
    y_train = np.array([x[1] for x in X_train_samples])
    y_train = labelizer.fit_transform(y_train) 
    y_train = to_categorical(y_train)

    #prepare validation data and labels
    x_val = np.array([x[0] for x in X_val_samples])
    y_val = np.array([x[1] for x in X_val_samples])
    y_val = labelizer.transform(y_val)
    y_val = to_categorical(y_val)

    #prepare test data and labels
    x_test = np.array([x[0] for x in X_test_samples])
    y_test = np.array([x[1] for x in X_test_samples])
    y_test = labelizer.transform(y_test)
    y_test = to_categorical(y_test)

    return x_train, y_train, x_val, y_val, x_test, y_test, labelizer

# %%
def plot_data(history, ss):
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    sns.set(font_scale=1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    plt.savefig('model_accuracy_size_'+str(ss)+'.png')
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()
    plt.savefig('model_loss_size_'+str(ss)+'.png')

# %%
def plot_conf_matrix(predictions, y_test, ss):
    sns.set(font_scale=2.5)
    matrix = confusion_matrix(labelizer.inverse_transform(y_test.argmax(axis=1)), 
                          labelizer.inverse_transform(predictions.argmax(axis=1)), 
                         labels=labelizer.classes_
                         )

    matrix = pd.DataFrame(matrix, index=labelizer.classes_, columns=labelizer.classes_)

    fig, ax = plt.subplots(figsize=(8, 8))

   
    sns.heatmap(matrix, annot=True, fmt='.2f', linewidth=5, cmap="Greens")
    ax.set_title('Confusion Matrix for (mis)classifications \n with fragment size: '+str(ss)+ ' seconds')
    ax.set_xlabel('Predictions')
    ax.set_ylabel('True values');

    fig.savefig('conf_matrix_size_'+str(ss)+'.png', bbox_inches='tight') #

# %%
#Main loop for testing multiple sample sizes

#choose model type: 'cnn' or 'lstm'
model_type = 'lstm'

n_epochs = 200
patience= 15
es = EarlyStopping(patience=15)
fragment_sizes = [5,10,15,30]
start = timeit.default_timer()

ModelData = pd.DataFrame(columns = ['Model Type','Fragment size (s)', 'Time to Compute (s)',  'Early Stopping epoch', 'Training accuracy', 'Validation accuracy', 'Test Accuracy']) #create a DataFrame for storing the results 

conf_matrix_data = []

for i in fragment_sizes:

    start_per_size = timeit.default_timer()

    print(f'\n---------- Model trained on fragments of size: {i} seconds ----------------')
    X_train_samples, X_test_samples, X_val_samples = retrieve_samples(i,model_type)
    x_train, y_train, x_val, y_val, x_test, y_test, labelizer = create_model_data_and_labels(X_train_samples, X_val_samples, X_test_samples)

    if model_type == 'cnn':
        model = create_cnn_model(X_train_samples[0][0].shape)
    elif model_type == 'lstm':
        model = create_lstm_model(X_train_samples[0][0].shape)


    history = model.fit(x_train, y_train, 
              batch_size = 8, 
              epochs=n_epochs,
              verbose=1, 
              callbacks=[es],
              validation_data=(x_val, y_val))
    print('Finished training')


    early_stopping_epoch = len(history.history['accuracy'])
    training_accuracy = history.history['accuracy'][early_stopping_epoch-1-patience]
    validation_accuracy = history.history['val_accuracy'][early_stopping_epoch-1-patience]

    plot_data(history, i)

    predictions = model.predict(x_test)
    score = accuracy_score(labelizer.inverse_transform(y_test.argmax(axis=1)), labelizer.inverse_transform(predictions.argmax(axis=1)))

    print('Fragment size = ' + str(i) + ' seconds')
    print('Accuracy on test samples: ' + str(score))
    
    conf_matrix_data += [(predictions, y_test, i)]

    stop_per_size = timeit.default_timer()
    time_to_compute = round(stop_per_size - start_per_size)

    print ('Time to compute: '+str(time_to_compute))

    ModelData.loc[len(ModelData)] = [model_type, i, time_to_compute, early_stopping_epoch, training_accuracy, validation_accuracy, score] #store particular settings configuration, early stoppping epoch and accuracies in dataframe

stop = timeit.default_timer()
print ('\ntime to compute: '+str(stop-start))
# Out:
# ---------- Model trained on fragments of size: 5 seconds ----------------
#
# Loading train samples
#  Progress: 100%
# Loading test samples
#  Progress: 100%
# Loading val samples
#  Progress: 100%
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1722 samples, validate on 431 samples
# Epoch 1/200
# 1722/1722 [==============================] - 54s 31ms/step - loss: 1.0563 - accuracy: 0.5348 - val_loss: 1.0304 - val_accuracy: 0.5731
# Epoch 2/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.8948 - accuracy: 0.6022 - val_loss: 0.9110 - val_accuracy: 0.6381
# Epoch 3/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.8316 - accuracy: 0.6469 - val_loss: 0.9570 - val_accuracy: 0.6404
# Epoch 4/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.8018 - accuracy: 0.6533 - val_loss: 0.9119 - val_accuracy: 0.6334
# Epoch 5/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.8102 - accuracy: 0.6609 - val_loss: 0.8681 - val_accuracy: 0.6705
# Epoch 6/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.7646 - accuracy: 0.6806 - val_loss: 0.8407 - val_accuracy: 0.6613
# Epoch 7/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.7364 - accuracy: 0.6870 - val_loss: 0.8944 - val_accuracy: 0.6288
# Epoch 8/200
# 1722/1722 [==============================] - 51s 30ms/step - loss: 0.7152 - accuracy: 0.7027 - val_loss: 0.8414 - val_accuracy: 0.6636
# Epoch 9/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.6912 - accuracy: 0.6974 - val_loss: 0.8570 - val_accuracy: 0.6195
# Epoch 10/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.6909 - accuracy: 0.7149 - val_loss: 0.9076 - val_accuracy: 0.6218
# Epoch 11/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.6572 - accuracy: 0.7352 - val_loss: 0.9083 - val_accuracy: 0.6450
# Epoch 12/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.6037 - accuracy: 0.7468 - val_loss: 0.7919 - val_accuracy: 0.6891
# Epoch 13/200
# 1722/1722 [==============================] - 51s 30ms/step - loss: 0.5914 - accuracy: 0.7642 - val_loss: 0.7554 - val_accuracy: 0.6589
# Epoch 14/200
# 1722/1722 [==============================] - 51s 30ms/step - loss: 0.5941 - accuracy: 0.7631 - val_loss: 0.7550 - val_accuracy: 0.6775
# Epoch 15/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.5497 - accuracy: 0.7822 - val_loss: 1.1358 - val_accuracy: 0.5128
# Epoch 16/200
# 1722/1722 [==============================] - 51s 30ms/step - loss: 0.5751 - accuracy: 0.7619 - val_loss: 0.7503 - val_accuracy: 0.6682
# Epoch 17/200
# 1722/1722 [==============================] - 51s 30ms/step - loss: 0.5179 - accuracy: 0.7875 - val_loss: 0.7984 - val_accuracy: 0.6821
# Epoch 18/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.4927 - accuracy: 0.8020 - val_loss: 0.7880 - val_accuracy: 0.6752
# Epoch 19/200
# 1722/1722 [==============================] - 51s 30ms/step - loss: 0.5345 - accuracy: 0.7904 - val_loss: 0.7919 - val_accuracy: 0.6845
# Epoch 20/200
# 1722/1722 [==============================] - 51s 30ms/step - loss: 0.4901 - accuracy: 0.8101 - val_loss: 0.8437 - val_accuracy: 0.6937
# Epoch 21/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.4730 - accuracy: 0.8200 - val_loss: 0.8558 - val_accuracy: 0.6984
# Epoch 22/200
# 1722/1722 [==============================] - 51s 30ms/step - loss: 0.4458 - accuracy: 0.8275 - val_loss: 0.7596 - val_accuracy: 0.7146
# Epoch 23/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.4285 - accuracy: 0.8310 - val_loss: 0.7297 - val_accuracy: 0.7216
# Epoch 24/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.4204 - accuracy: 0.8374 - val_loss: 0.7908 - val_accuracy: 0.6961
# Epoch 25/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.4216 - accuracy: 0.8345 - val_loss: 0.8368 - val_accuracy: 0.7146
# Epoch 26/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.4070 - accuracy: 0.8409 - val_loss: 0.9004 - val_accuracy: 0.6613
# Epoch 27/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.3925 - accuracy: 0.8525 - val_loss: 0.7913 - val_accuracy: 0.6984
# Epoch 28/200
# 1722/1722 [==============================] - 52s 30ms/step - loss: 0.4250 - accuracy: 0.8397 - val_loss: 0.7583 - val_accuracy: 0.7193
# Epoch 29/200
# 1722/1722 [==============================] - 53s 31ms/step - loss: 0.3508 - accuracy: 0.8612 - val_loss: 0.8266 - val_accuracy: 0.7239
# Epoch 30/200
# 1722/1722 [==============================] - 53s 31ms/step - loss: 0.3576 - accuracy: 0.8676 - val_loss: 0.7106 - val_accuracy: 0.7123
# Epoch 31/200
# 1722/1722 [==============================] - 53s 31ms/step - loss: 0.3617 - accuracy: 0.8641 - val_loss: 0.8104 - val_accuracy: 0.7169
# Epoch 32/200
# 1722/1722 [==============================] - 53s 31ms/step - loss: 0.3598 - accuracy: 0.8589 - val_loss: 0.9234 - val_accuracy: 0.6961
# Epoch 33/200
# 1722/1722 [==============================] - 53s 31ms/step - loss: 0.3382 - accuracy: 0.8717 - val_loss: 0.8629 - val_accuracy: 0.7169
# Epoch 34/200
# 1722/1722 [==============================] - 53s 31ms/step - loss: 0.3390 - accuracy: 0.8717 - val_loss: 0.9129 - val_accuracy: 0.7146
# Epoch 35/200
# 1722/1722 [==============================] - 53s 31ms/step - loss: 0.3205 - accuracy: 0.8798 - val_loss: 0.8629 - val_accuracy: 0.7216
# Epoch 36/200
# 1722/1722 [==============================] - 53s 31ms/step - loss: 0.3287 - accuracy: 0.8711 - val_loss: 0.8131 - val_accuracy: 0.7541
# Epoch 37/200
# 1722/1722 [==============================] - 53s 31ms/step - loss: 0.3373 - accuracy: 0.8780 - val_loss: 0.7668 - val_accuracy: 0.7332
# Epoch 38/200
# 1722/1722 [==============================] - 53s 31ms/step - loss: 0.2973 - accuracy: 0.8850 - val_loss: 0.8785 - val_accuracy: 0.7355
# Epoch 39/200
# 1722/1722 [==============================] - 53s 31ms/step - loss: 0.3472 - accuracy: 0.8647 - val_loss: 0.8059 - val_accuracy: 0.7401
# Epoch 40/200
# 1722/1722 [==============================] - 53s 31ms/step - loss: 0.2971 - accuracy: 0.8949 - val_loss: 0.7422 - val_accuracy: 0.7541
# Epoch 41/200
# 1722/1722 [==============================] - 53s 31ms/step - loss: 0.2904 - accuracy: 0.8966 - val_loss: 0.9410 - val_accuracy: 0.7146
# Epoch 42/200
# 1722/1722 [==============================] - 53s 31ms/step - loss: 0.2599 - accuracy: 0.9077 - val_loss: 0.8449 - val_accuracy: 0.7401
# Epoch 43/200
# 1722/1722 [==============================] - 53s 31ms/step - loss: 0.2903 - accuracy: 0.8856 - val_loss: 0.9964 - val_accuracy: 0.6984
# Epoch 44/200
# 1722/1722 [==============================] - 53s 31ms/step - loss: 0.2477 - accuracy: 0.9111 - val_loss: 0.8638 - val_accuracy: 0.7471
# Epoch 45/200
# 1722/1722 [==============================] - 53s 30ms/step - loss: 0.2703 - accuracy: 0.9024 - val_loss: 0.8814 - val_accuracy: 0.7169
# Finished training
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])
# Fragment size = 5 seconds
# Accuracy on test samples: 0.8041666666666667
# Time to compute: 2903
#
# ---------- Model trained on fragments of size: 10 seconds ----------------
#
# Loading train samples
#  Progress: 100%
# Loading test samples
#  Progress: 100%
# Loading val samples
#  Progress: 100%
#
# Train on 858 samples, validate on 215 samples
# Epoch 1/200
# 858/858 [==============================] - 27s 31ms/step - loss: 1.0999 - accuracy: 0.5268 - val_loss: 1.1834 - val_accuracy: 0.5349
# Epoch 2/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.9074 - accuracy: 0.6096 - val_loss: 0.9463 - val_accuracy: 0.5814
# Epoch 3/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.8715 - accuracy: 0.6189 - val_loss: 0.9060 - val_accuracy: 0.6326
# Epoch 4/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.8137 - accuracy: 0.6538 - val_loss: 0.8400 - val_accuracy: 0.6140
# Epoch 5/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.8058 - accuracy: 0.6643 - val_loss: 0.9062 - val_accuracy: 0.5907
# Epoch 6/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.7394 - accuracy: 0.7086 - val_loss: 0.8745 - val_accuracy: 0.6512
# Epoch 7/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.7395 - accuracy: 0.6737 - val_loss: 0.8129 - val_accuracy: 0.6651
# Epoch 8/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.7339 - accuracy: 0.6970 - val_loss: 0.8327 - val_accuracy: 0.6651
# Epoch 9/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.7007 - accuracy: 0.7179 - val_loss: 0.8819 - val_accuracy: 0.6326
# Epoch 10/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.6922 - accuracy: 0.7110 - val_loss: 1.0792 - val_accuracy: 0.6093
# Epoch 11/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.6887 - accuracy: 0.7179 - val_loss: 0.8919 - val_accuracy: 0.6605
# Epoch 12/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.6553 - accuracy: 0.7319 - val_loss: 0.8174 - val_accuracy: 0.6837
# Epoch 13/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.6593 - accuracy: 0.7424 - val_loss: 0.8365 - val_accuracy: 0.6512
# Epoch 14/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.6014 - accuracy: 0.7599 - val_loss: 0.9304 - val_accuracy: 0.6279
# Epoch 15/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.5942 - accuracy: 0.7529 - val_loss: 0.8808 - val_accuracy: 0.6465
# Epoch 16/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.5935 - accuracy: 0.7657 - val_loss: 0.9945 - val_accuracy: 0.6279
# Epoch 17/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.5690 - accuracy: 0.7879 - val_loss: 0.9377 - val_accuracy: 0.6419
# Epoch 18/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.5226 - accuracy: 0.7949 - val_loss: 1.0539 - val_accuracy: 0.5953
# Epoch 19/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.5426 - accuracy: 0.7914 - val_loss: 0.8922 - val_accuracy: 0.6558
# Epoch 20/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.5298 - accuracy: 0.7995 - val_loss: 1.0369 - val_accuracy: 0.6326
# Epoch 21/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.5977 - accuracy: 0.7855 - val_loss: 0.8642 - val_accuracy: 0.6372
# Epoch 22/200
# 858/858 [==============================] - 26s 30ms/step - loss: 0.5739 - accuracy: 0.7774 - val_loss: 0.9467 - val_accuracy: 0.6233
# Finished training
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])
# Fragment size = 10 seconds
# Accuracy on test samples: 0.7083333333333334
# Time to compute: 952
#
# ---------- Model trained on fragments of size: 15 seconds ----------------
#
# Loading train samples
#  Progress: 100%
# Loading test samples
#  Progress: 100%
# Loading val samples
#  Progress: 100%
#
# Train on 570 samples, validate on 143 samples
# Epoch 1/200
# 570/570 [==============================] - 18s 31ms/step - loss: 1.1177 - accuracy: 0.5070 - val_loss: 0.9776 - val_accuracy: 0.5804
# Epoch 2/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.9367 - accuracy: 0.5965 - val_loss: 0.9245 - val_accuracy: 0.6573
# Epoch 3/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.8754 - accuracy: 0.6281 - val_loss: 1.0575 - val_accuracy: 0.5455
# Epoch 4/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.8297 - accuracy: 0.6614 - val_loss: 0.9110 - val_accuracy: 0.6154
# Epoch 5/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.9495 - accuracy: 0.5667 - val_loss: 0.9276 - val_accuracy: 0.6643
# Epoch 6/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.8213 - accuracy: 0.6789 - val_loss: 0.8464 - val_accuracy: 0.6783
# Epoch 7/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.7949 - accuracy: 0.6772 - val_loss: 1.0289 - val_accuracy: 0.5315
# Epoch 8/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.8903 - accuracy: 0.6333 - val_loss: 1.1013 - val_accuracy: 0.5944
# Epoch 9/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.7906 - accuracy: 0.6632 - val_loss: 1.1493 - val_accuracy: 0.6364
# Epoch 10/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.7736 - accuracy: 0.6982 - val_loss: 0.8957 - val_accuracy: 0.6434
# Epoch 11/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.7752 - accuracy: 0.6982 - val_loss: 0.9577 - val_accuracy: 0.6294
# Epoch 12/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.7380 - accuracy: 0.6842 - val_loss: 0.9133 - val_accuracy: 0.6084
# Epoch 13/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.6930 - accuracy: 0.7193 - val_loss: 0.8810 - val_accuracy: 0.6503
# Epoch 14/200
# 570/570 [==============================] - 17s 31ms/step - loss: 0.6919 - accuracy: 0.7404 - val_loss: 0.8722 - val_accuracy: 0.6434
# Epoch 15/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.6895 - accuracy: 0.7456 - val_loss: 0.8974 - val_accuracy: 0.6853
# Epoch 16/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.7095 - accuracy: 0.7053 - val_loss: 0.8911 - val_accuracy: 0.6364
# Epoch 17/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.6477 - accuracy: 0.7439 - val_loss: 0.8281 - val_accuracy: 0.6643
# Epoch 18/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.6550 - accuracy: 0.7421 - val_loss: 0.9944 - val_accuracy: 0.6643
# Epoch 19/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.6570 - accuracy: 0.7456 - val_loss: 1.0536 - val_accuracy: 0.6154
# Epoch 20/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.6234 - accuracy: 0.7684 - val_loss: 0.8933 - val_accuracy: 0.6503
# Epoch 21/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.5429 - accuracy: 0.7947 - val_loss: 0.8997 - val_accuracy: 0.6224
# Epoch 22/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.5562 - accuracy: 0.7930 - val_loss: 0.9015 - val_accuracy: 0.5944
# Epoch 23/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.5724 - accuracy: 0.7789 - val_loss: 0.9377 - val_accuracy: 0.6434
# Epoch 24/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.5442 - accuracy: 0.7895 - val_loss: 0.9907 - val_accuracy: 0.5874
# Epoch 25/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.5367 - accuracy: 0.8018 - val_loss: 0.8168 - val_accuracy: 0.6713
# Epoch 26/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.4980 - accuracy: 0.8158 - val_loss: 1.1392 - val_accuracy: 0.6503
# Epoch 27/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.4940 - accuracy: 0.8140 - val_loss: 0.9593 - val_accuracy: 0.6014
# Epoch 28/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.5979 - accuracy: 0.7684 - val_loss: 0.8706 - val_accuracy: 0.6503
# Epoch 29/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.4962 - accuracy: 0.8228 - val_loss: 1.0119 - val_accuracy: 0.5804
# Epoch 30/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.4654 - accuracy: 0.8368 - val_loss: 1.0068 - val_accuracy: 0.6294
# Epoch 31/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.4652 - accuracy: 0.8228 - val_loss: 0.9976 - val_accuracy: 0.6573
# Epoch 32/200
# 570/570 [==============================] - 17s 31ms/step - loss: 0.4916 - accuracy: 0.8070 - val_loss: 0.8866 - val_accuracy: 0.6084
# Epoch 33/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.4446 - accuracy: 0.8421 - val_loss: 0.8927 - val_accuracy: 0.6364
# Epoch 34/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.4120 - accuracy: 0.8456 - val_loss: 0.8534 - val_accuracy: 0.6643
# Epoch 35/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.4203 - accuracy: 0.8368 - val_loss: 0.9658 - val_accuracy: 0.6713
# Epoch 36/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.4413 - accuracy: 0.8298 - val_loss: 0.8258 - val_accuracy: 0.6503
# Epoch 37/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.3764 - accuracy: 0.8509 - val_loss: 1.4823 - val_accuracy: 0.5524
# Epoch 38/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.4223 - accuracy: 0.8333 - val_loss: 1.0879 - val_accuracy: 0.6573
# Epoch 39/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.3498 - accuracy: 0.8596 - val_loss: 0.9814 - val_accuracy: 0.6573
# Epoch 40/200
# 570/570 [==============================] - 17s 30ms/step - loss: 0.3638 - accuracy: 0.8702 - val_loss: 1.2765 - val_accuracy: 0.5874
# Finished training
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])
# Fragment size = 15 seconds
# Accuracy on test samples: 0.6375
# Time to compute: 990
#
# ---------- Model trained on fragments of size: 30 seconds ----------------
#
# Loading train samples
#  Progress: 100%
# Loading test samples
#  Progress: 100%
# Loading val samples
#  Progress: 100%
#
# Train on 282 samples, validate on 71 samples
# Epoch 1/200
# 282/282 [==============================] - 9s 33ms/step - loss: 1.1378 - accuracy: 0.4894 - val_loss: 1.4447 - val_accuracy: 0.4507
# Epoch 2/200
# 282/282 [==============================] - 9s 31ms/step - loss: 1.0162 - accuracy: 0.5816 - val_loss: 1.0520 - val_accuracy: 0.5352
# Epoch 3/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.8814 - accuracy: 0.6277 - val_loss: 0.8565 - val_accuracy: 0.6056
# Epoch 4/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.8883 - accuracy: 0.6348 - val_loss: 0.9295 - val_accuracy: 0.5775
# Epoch 5/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.8437 - accuracy: 0.6489 - val_loss: 1.0090 - val_accuracy: 0.5775
# Epoch 6/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.8191 - accuracy: 0.6773 - val_loss: 0.9324 - val_accuracy: 0.6056
# Epoch 7/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.7554 - accuracy: 0.7092 - val_loss: 0.9736 - val_accuracy: 0.5634
# Epoch 8/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.8662 - accuracy: 0.6383 - val_loss: 1.4171 - val_accuracy: 0.3944
# Epoch 9/200
# 282/282 [==============================] - 9s 31ms/step - loss: 1.1333 - accuracy: 0.5390 - val_loss: 1.2663 - val_accuracy: 0.3662
# Epoch 10/200
# 282/282 [==============================] - 9s 30ms/step - loss: 0.9463 - accuracy: 0.5780 - val_loss: 1.0879 - val_accuracy: 0.5634
# Epoch 11/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.8252 - accuracy: 0.6348 - val_loss: 0.9064 - val_accuracy: 0.6197
# Epoch 12/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.7625 - accuracy: 0.7021 - val_loss: 1.0549 - val_accuracy: 0.6338
# Epoch 13/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.8581 - accuracy: 0.6809 - val_loss: 1.0189 - val_accuracy: 0.6338
# Epoch 14/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.7735 - accuracy: 0.6915 - val_loss: 1.1296 - val_accuracy: 0.6056
# Epoch 15/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.6871 - accuracy: 0.7589 - val_loss: 1.4561 - val_accuracy: 0.5352
# Epoch 16/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.7377 - accuracy: 0.7163 - val_loss: 0.9623 - val_accuracy: 0.6620
# Epoch 17/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.6711 - accuracy: 0.7305 - val_loss: 1.0168 - val_accuracy: 0.6479
# Epoch 18/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.6401 - accuracy: 0.7553 - val_loss: 0.8986 - val_accuracy: 0.6479
# Finished training
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])
# Fragment size = 30 seconds
# Accuracy on test samples: 0.75
# Time to compute: 357
#
# time to compute: 5201.373161953

# %%
print(ModelData)

ModelData.head()

import os.path
from google.colab import files


filenumber=1
while os.path.isfile('ModelData'+str(filenumber)+'.csv'): #find the first free file
    filenumber += 1

ModelData.to_csv(r'ModelData'+str(filenumber)+'.csv') #store data in the first free csv file
# files.download('ModelData'+str(filenumber)+'.csv') #download csv file
# Out:
#   Model Type Fragment size (s)  ... Validation accuracy Test Accuracy
# 0       lstm                 5  ...            0.712297      0.804167
# 1       lstm                10  ...            0.665116      0.708333
# 2       lstm                15  ...            0.671329      0.637500
# 3       lstm                30  ...            0.605634      0.750000
#
# [4 rows x 7 columns]

# %%
#reads a csv file and converts it to a LaTeX table
# ModelDataLatex = pd.read_csv('ModelData2.csv') #select which csv file to use here
print(ModelData.to_latex(index=False))
# Out:
# \begin{tabular}{llllrrr}
# \toprule
# Model Type & Fragment size (s) & Time to Compute (s) & Early Stopping epoch &  Training accuracy &  Validation accuracy &  Test Accuracy \\
# \midrule
#       lstm &                 5 &                2903 &                   45 &           0.867596 &             0.712297 &       0.804167 \\
#       lstm &                10 &                 952 &                   22 &           0.673660 &             0.665116 &       0.708333 \\
#       lstm &                15 &                 990 &                   40 &           0.801754 &             0.671329 &       0.637500 \\
#       lstm &                30 &                 357 &                   18 &           0.627660 &             0.605634 &       0.750000 \\
# \bottomrule
# \end{tabular}

# %%
#plot confusion matrices for the given input sample sizes
for j in conf_matrix_data:
    plot_conf_matrix(j[0], j[1], j[2])
